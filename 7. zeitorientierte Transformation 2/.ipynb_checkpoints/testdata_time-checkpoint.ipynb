# %%
__version__ = '0.3'
__author__  = "Robert Matern (r.matern@stud.uni-hannover.de)"
__date__    = ''
__url__     = ''
__copyright__ = "(C) 2015 Robert Matern"

# %% [markdown]
# #Beispieldaten Nr. 1

# %%
# Funktionen werden hinzugeladen.
# %run Parameter.ipynb

# %%
# Produkte
products = Product(3)

# Ressourcen 
resources = Resource(3)

#Kapazität
capacities = Capacity(resources)
capacities[1] = 1
capacities[2] = 1
capacities[3] = 1

# Ressourcenverbrauch
# Achtung! Hier eine Dimensionsreduzierung !!!
consumtions = Consumption(products, resources)
consumtions[1] = [0,1,0,0]
consumtions[2] = [0,0,1,0]
consumtions[3] = [0,0,0,2]

# Erträge
revenues = Revenue(products)
revenues[1] = 100
revenues[2] = 200
revenues[3] = 5000

# Buchungsperioden
times = Time(3)

# Wahrscheinlichkeiten
probs = Prob(products, times)
probs[1] = [0, 0.3, 0.3, 0.3]
probs[2] = [0, 0.3, 0.3, 0]
probs[3] = [0, 0.3, 0, 0]

# Gegenwahrscheinlichkeiten
against_probs = Against_Prob(probs)
probs[0] = against_probs

# Systemzustände
conditions = Condition(capacities, resources, times)


# Endzeitpunkte
#end_times = End_Time(conditions)
# Out:
# 0:00:00.000440

# %% [markdown]
# inkl. Lagerhaltung

# %%
#Lagerbestand
stock_resources = Stock_Resource(resources)
stock_resources[1] = 0

max_stock_resources = Max_Stock_Resource(resources)
max_stock_resources[1] = 2
max_stock_resources[2] = 2
max_stock_resources[3] = 2

# Systemzustände
condition_storages = Condition_Storage(capacities, resources, max_stock_resources, times)
# Bei der Modelformulierung mit Lagerproduktion wird der Parameter 'max_stocks' benötigt.
# Out:
# 0:00:00.002618

# %%
# %run DynamicProgramm_time2.ipynb

# %%
solutions = {}

DP_Time(solutions, condition_storages, products, resources, capacities, consumtions, times, revenues, probs, stock_resources, max_stock_resources)
# Out:
# c[h]: [1 1 1] - y[h]: [0 0 0] - t: 0 - d(c,y,t): [0 0 0] - V(c,y,t): 0.0 - j*: 0 - OC[j*]: 0
# c[h]: [0 1 1] - y[h]: [0 0 0] - t: 0 - d(c,y,t): [0 0 0] - V(c,y,t): 0.0 - j*: 0 - OC[j*]: 0
# c[h]: [0 1 1] - y[h]: [0 1 0] - t: 0 - d(c,y,t): [0 0 0] - V(c,y,t): 0.0 - j*: 0 - OC[j*]: 0
# c[h]: [1 0 1] - y[h]: [0 0 0] - t: 0 - d(c,y,t): [0 0 0] - V(c,y,t): 0.0 - j*: 0 - OC[j*]: 0
# c[h]: [1 0 1] - y[h]: [0 0 1] - t: 0 - d(c,y,t): [0 0 0] - V(c,y,t): 0.0 - j*: 0 - OC[j*]: 0
# c[h]: [1 1 1] - y[h]: [0 0 0] - t: 1 - d(c,y,t): [1 1 0] - V(c,y,t): 90.0 - j*: 2 - OC[j*]: 200.0
# c[h]: [0 0 1] - y[h]: [0 0 0] - t: 0 - d(c,y,t): [0 0 0] - V(c,y,t): 0.0 - j*: 0 - OC[j*]: 0
# c[h]: [0 0 1] - y[h]: [0 0 1] - t: 0 - d(c,y,t): [0 0 0] - V(c,y,t): 0.0 - j*: 0 - OC[j*]: 0
# c[h]: [0 1 1] - y[h]: [0 0 0] - t: 1 - d(c,y,t): [0 1 0] - V(c,y,t): 60.0 - j*: 2 - OC[j*]: 200.0
# c[h]: [0 0 1] - y[h]: [0 1 0] - t: 0 - d(c,y,t): [0 0 0] - V(c,y,t): 0.0 - j*: 0 - OC[j*]: 0
# c[h]: [0 0 1] - y[h]: [0 1 1] - t: 0 - d(c,y,t): [0 0 0] - V(c,y,t): 0.0 - j*: 0 - OC[j*]: 0
# c[h]: [0 1 1] - y[h]: [0 1 0] - t: 1 - d(c,y,t): [0 1 0] - V(c,y,t): 60.0 - j*: 2 - OC[j*]: 200.0
# c[h]: [1 0 1] - y[h]: [0 0 0] - t: 1 - d(c,y,t): [1 0 0] - V(c,y,t): 30.0 - j*: 1 - OC[j*]: 100.0
# c[h]: [1 0 1] - y[h]: [0 0 1] - t: 1 - d(c,y,t): [1 0 0] - V(c,y,t): 30.0 - j*: 1 - OC[j*]: 100.0
# c[h]: [1 1 1] - y[h]: [0 0 0] - t: 2 - d(c,y,t): [1 1 0] - V(c,y,t): 153.0 - j*: 2 - OC[j*]: 140.0
# c[h]: [0 0 1] - y[h]: [0 0 0] - t: 1 - d(c,y,t): [0 0 0] - V(c,y,t): 0.0 - j*: 0 - OC[j*]: 0
# c[h]: [0 0 1] - y[h]: [0 0 1] - t: 1 - d(c,y,t): [0 0 0] - V(c,y,t): 0.0 - j*: 0 - OC[j*]: 0
# c[h]: [0 1 1] - y[h]: [0 0 0] - t: 2 - d(c,y,t): [0 1 0] - V(c,y,t): 102.0 - j*: 2 - OC[j*]: 140.0
# c[h]: [0 0 1] - y[h]: [0 1 0] - t: 1 - d(c,y,t): [0 2 0] - V(c,y,t): 60.0 - j*: 2 - OC[j*]: 200.0
# c[h]: [0 0 1] - y[h]: [0 1 1] - t: 1 - d(c,y,t): [0 2 0] - V(c,y,t): 60.0 - j*: 2 - OC[j*]: 200.0
# c[h]: [0 1 1] - y[h]: [0 1 0] - t: 2 - d(c,y,t): [0 1 0] - V(c,y,t): 120.0 - j*: 2 - OC[j*]: 200.0
# c[h]: [1 1 1] - y[h]: [0 0 0] - t: 3 - d(c,y,t): [1 0 0] - V(c,y,t): 167.703 - j*: 1 - OC[j*]: 49.0
# 167.70312

# %%
graph = Structure_Transform(solutions, condition_storages, products, resources, consumtions, revenues, probs, stock_resources, max_stock_resources)

# %%
Opt_Politic_Stock(solutions, resources, stock_resources, products)
# Out:
#      $c^{1}$  $c^{2}$  $c^{3}$  $y^{1}$  $y^{2}$  $y^{3}$  $t$    ExpValue  \
# 524        0        1        1        0        1        0    0    0.000000
# 525        0        1        1        0        1        0    1   60.000000
# 526        0        1        1        0        1        0    2  120.000000
# 536        0        1        1        0        0        0    0    0.000000
# 537        0        1        1        0        0        0    1   60.000000
# 538        0        1        1        0        0        0    2  102.000000
# 316        1        0        1        0        0        1    0    0.000000
# 317        1        0        1        0        0        1    1   30.000000
# 320        1        0        1        0        0        0    0    0.000000
# 321        1        0        1        0        0        0    1   30.000000
# 736        0        0        1        0        1        1    0    0.000000
# 737        0        0        1        0        1        1    1   60.000000
# 740        0        0        1        0        1        0    0    0.000000
# 741        0        0        1        0        1        0    1   60.000000
# 104        1        1        1        0        0        0    0    0.000000
# 105        1        1        1        0        0        0    1   90.000000
# 106        1        1        1        0        0        0    2  153.000000
# 107        1        1        1        0        0        0    3  167.703125
# 748        0        0        1        0        0        1    0    0.000000
# 749        0        0        1        0        0        1    1    0.000000
# 752        0        0        1        0        0        0    0    0.000000
#
#      $d_{1}$  $d_{2}$  $d_{3}$
# 524        0        0        0
# 525        0        1        0
# 526        0        1        0
# 536        0        0        0
# 537        0        1        0
# 538        0        1        0
# 316        0        0        0
# 317        1        0        0
# 320        0        0        0
# 321        1        0        0
# 736        0        0        0
# 737        0        2        0
# 740        0        0        0
# 741        0        2        0
# 104        0        0        0
# 105        1        1        0
# 106        1        1        0
# 107        1        0        0
# 748        0        0        0
# 749        0        0        0
# 752        0        0        0

# %%
import matplotlib as plt

draw = graph.copy()
draw.remove_node('end')
        # Quelle: http://stackoverflow.com/a/11484144/4913569
        # ----
        # write dot file to use with graphviz
        # run "dot -Tpng test.dot >test.png"
nx.write_dot(draw,'test.dot')

        # same layout using matplotlib with no labels
#pos=nx.graphviz_layout(draw,prog='dot')
#plt.figure(figsize=(size_x,size_y))
#plt.title("Entscheidungsbaum")
#nx.draw(draw,pos,with_labels=True, node_size=500)
#plt.savefig('GraphTest.png')
